# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

vaccinations_df = pd.read_csv('Resources/country_vaccinations.csv')
vaccinations_df.head(100)
# Out:
#     country iso_code        date  total_vaccinations  people_vaccinated  \
# 0   Algeria      DZA  2021-01-29                 0.0                NaN
# 1   Algeria      DZA  2021-01-30                30.0                NaN
# 2   Andorra      AND  2021-01-25               576.0              576.0
# 3   Andorra      AND  2021-01-26                 NaN                NaN
# 4   Andorra      AND  2021-01-27                 NaN                NaN
# ..      ...      ...         ...                 ...                ...
# 95  Bahrain      BHR  2021-01-18            142831.0           142831.0
# 96  Bahrain      BHR  2021-01-19            143596.0           143596.0
# 97  Bahrain      BHR  2021-01-20            144130.0           144130.0
# 98  Bahrain      BHR  2021-01-21                 NaN                NaN
# 99  Bahrain      BHR  2021-01-22                 NaN                NaN
#
#     people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %%
df_modified = vaccinations_df[["country","date", "total_vaccinations","people_fully_vaccinated",
                               "daily_vaccinations",'people_fully_vaccinated_per_hundred',
                               'daily_vaccinations_per_million','vaccines']]


df_country=df_modified.groupby("country")

df_dailyvaccinations = df_country['daily_vaccinations_per_million'].sum()
df_dailyvaccinations = df_dailyvaccinations.sort_values(axis = 0, 
                    ascending = False)
df_dailyvaccinations.head
                               
# #country = []
# #value = []
# #for i in range(10):
#     a = df_per.iloc[0]["country"]
#     b = df_per.iloc[0]["total_vaccinations"]
#     country.append(a)
#     value.append(b)
#     df_per = df_per.drop(df_per[df_per["country"]==a].index)
#     df_per = df_per.reset_index(drop=True)

# df_per.head
# Out:
# <bound method NDFrame.head of country
# Israel                  556966.0
# Gibraltar               450924.0
# Seychelles              255939.0
# United Arab Emirates    234283.0
# England                 129370.0
#                           ...
# Myanmar                     70.0
# Maldives                    67.0
# Egypt                       12.0
# Algeria                      1.0
# Faeroe Islands               0.0
# Name: daily_vaccinations_per_million, Length: 72, dtype: float64>

# %%
df_modified_rename = df_modified.rename(columns={'country': 'Country', 'date': 'Date', 'total_vaccinations': 'Total Vaccinations',  
                   'people_fully_vaccinated': 'People Fully Vaccinated', 'daily_vaccinations': 'Daily Vaccinations', 
                   'people_fully_vaccinated_per_hundred': 'People Fully Vaccinated Per Hundred', 
                   'daily_vaccinations_per_million': 'Daily Vaccinations Per Million', 
                   'vaccines': 'Vaccines'})
df_modified_rename.dropna()
df_modified_rename.head()
# Out:
#    Country        Date  Total Vaccinations  People Fully Vaccinated  \
# 0  Algeria  2021-01-29                 0.0                      NaN
# 1  Algeria  2021-01-30                30.0                      NaN
# 2  Andorra  2021-01-25               576.0                      NaN
# 3  Andorra  2021-01-26                 NaN                      NaN
# 4  Andorra  2021-01-27                 NaN                      NaN
#
#    Daily Vaccinations  People Fully Vaccinated Per Hundred  \
# 0                 NaN                                  NaN
# 1                30.0                                  NaN
# 2                 NaN                                  NaN
# 3                66.0                                  NaN
# 4                66.0                                  NaN
#
#    Daily Vaccinations Per Million         Vaccines
# 0                             NaN        Sputnik V
# 1                             1.0        Sputnik V
# ...
