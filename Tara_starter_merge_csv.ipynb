# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

vaccinations_df = pd.read_csv('Resources/country_vaccinations.csv')
vaccinations_df.head(20)
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Algeria      DZA   1/29/2021                 0.0                NaN
# 1     Algeria      DZA   1/30/2021                30.0                NaN
# 2     Andorra      AND   1/25/2021               576.0              576.0
# 3     Andorra      AND   1/26/2021                 NaN                NaN
# 4     Andorra      AND   1/27/2021                 NaN                NaN
# 5     Andorra      AND   1/28/2021                 NaN                NaN
# 6     Andorra      AND   1/29/2021                 NaN                NaN
# 7     Andorra      AND   1/30/2021                 NaN                NaN
# 8     Andorra      AND   1/31/2021                 NaN                NaN
# 9     Andorra      AND    2/1/2021              1036.0             1036.0
# 10  Argentina      ARG  12/29/2020               700.0                NaN
# 11  Argentina      ARG  12/30/2020                 NaN                NaN
# 12  Argentina      ARG  12/31/2020             32013.0                NaN
# 13  Argentina      ARG    1/1/2021                 NaN                NaN
# 14  Argentina      ARG    1/2/2021                 NaN                NaN
# 15  Argentina      ARG    1/3/2021                 NaN                NaN
# 16  Argentina      ARG    1/4/2021             39599.0                NaN
# 17  Argentina      ARG    1/5/2021                 NaN                NaN
# 18  Argentina      ARG    1/6/2021                 NaN                NaN
# 19  Argentina      ARG    1/7/2021                 NaN                NaN
#
#     people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                    30.0                30.0
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                66.0
# 4                       NaN                     NaN                66.0
# 5                       NaN                     NaN                66.0
# 6                       NaN                     NaN                66.0
# 7                       NaN                     NaN                66.0
# 8                       NaN                     NaN                66.0
# 9                       NaN                     NaN                66.0
# 10                      NaN                     NaN                 NaN
# 11                      NaN                     NaN             15656.0
# 12                      NaN                     NaN             15656.0
# 13                      NaN                     NaN             11070.0
# 14                      NaN                     NaN              8776.0
# 15                      NaN                     NaN              7400.0
# 16                      NaN                     NaN              6483.0
# 17                      NaN                     NaN              7984.0
# 18                      NaN                     NaN              8173.0
# 19                      NaN                     NaN              8363.0
#
#     total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.00                            NaN
# 1                             0.00                            NaN
# 2                             0.75                           0.75
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# 5                              NaN                            NaN
# 6                              NaN                            NaN
# 7                              NaN                            NaN
# 8                              NaN                            NaN
# 9                             1.34                           1.34
# 10                            0.00                            NaN
# 11                             NaN                            NaN
# 12                            0.07                            NaN
# 13                             NaN                            NaN
# 14                             NaN                            NaN
# 15                             NaN                            NaN
# 16                            0.09                            NaN
# 17                             NaN                            NaN
# 18                             NaN                            NaN
# 19                             NaN                            NaN
#
#     people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                   NaN                             NaN
# 1                                   NaN                             1.0
# 2                                   NaN                             NaN
# 3                                   NaN                           854.0
# 4                                   NaN                           854.0
# 5                                   NaN                           854.0
# 6                                   NaN                           854.0
# 7                                   NaN                           854.0
# 8                                   NaN                           854.0
# 9                                   NaN                           854.0
# 10                                  NaN                             NaN
# 11                                  NaN                           346.0
# 12                                  NaN                           346.0
# 13                                  NaN                           245.0
# 14                                  NaN                           194.0
# 15                                  NaN                           164.0
# 16                                  NaN                           143.0
# 17                                  NaN                           177.0
# 18                                  NaN                           181.0
# 19                                  NaN                           185.0
#
#            vaccines            source_name  \
# 0         Sputnik V     Ministry of Health
# 1         Sputnik V     Ministry of Health
# 2   Pfizer/BioNTech  Government of Andorra
# 3   Pfizer/BioNTech  Government of Andorra
# 4   Pfizer/BioNTech  Government of Andorra
# 5   Pfizer/BioNTech  Government of Andorra
# 6   Pfizer/BioNTech  Government of Andorra
# 7   Pfizer/BioNTech  Government of Andorra
# 8   Pfizer/BioNTech  Government of Andorra
# 9   Pfizer/BioNTech  Government of Andorra
# 10        Sputnik V     Ministry of Health
# 11        Sputnik V     Ministry of Health
# 12        Sputnik V     Ministry of Health
# 13        Sputnik V     Ministry of Health
# 14        Sputnik V     Ministry of Health
# 15        Sputnik V     Ministry of Health
# 16        Sputnik V     Ministry of Health
# 17        Sputnik V     Ministry of Health
# 18        Sputnik V     Ministry of Health
# 19        Sputnik V     Ministry of Health
#
#                                        source_website
# 0   https://www.aps.dz/regions/116777-blida-covid-...
# 1   https://www.aps.dz/regions/116777-blida-covid-...
# 2   https://www.govern.ad/comunicats/item/12379-se...
# 3   https://www.govern.ad/comunicats/item/12379-se...
# 4   https://www.govern.ad/comunicats/item/12379-se...
# 5   https://www.govern.ad/comunicats/item/12379-se...
# 6   https://www.govern.ad/comunicats/item/12379-se...
# 7   https://www.govern.ad/comunicats/item/12379-se...
# 8   https://www.govern.ad/comunicats/item/12379-se...
# 9   https://www.govern.ad/comunicats/item/12379-se...
# 10  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 11  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 12  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 13  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 14  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 15  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 16  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 17  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 18  http://datos.salud.gob.ar/dataset/vacunas-cont...
# 19  http://datos.salud.gob.ar/dataset/vacunas-cont...

# %%
# identify csv
owid_data_df = pd.read_csv('Resources/owid-covid-data.csv')
owid_data_df.head(20)
# Out:
#    iso_code continent     location       date  total_cases  new_cases  \
# 0       AFG      Asia  Afghanistan  2/24/2020          1.0        1.0
# 1       AFG      Asia  Afghanistan  2/25/2020          1.0        0.0
# 2       AFG      Asia  Afghanistan  2/26/2020          1.0        0.0
# 3       AFG      Asia  Afghanistan  2/27/2020          1.0        0.0
# 4       AFG      Asia  Afghanistan  2/28/2020          1.0        0.0
# 5       AFG      Asia  Afghanistan  2/29/2020          1.0        0.0
# 6       AFG      Asia  Afghanistan   3/1/2020          1.0        0.0
# 7       AFG      Asia  Afghanistan   3/2/2020          1.0        0.0
# 8       AFG      Asia  Afghanistan   3/3/2020          2.0        1.0
# 9       AFG      Asia  Afghanistan   3/4/2020          4.0        2.0
# 10      AFG      Asia  Afghanistan   3/5/2020          4.0        0.0
# 11      AFG      Asia  Afghanistan   3/6/2020          4.0        0.0
# 12      AFG      Asia  Afghanistan   3/7/2020          4.0        0.0
# 13      AFG      Asia  Afghanistan   3/8/2020          5.0        1.0
# 14      AFG      Asia  Afghanistan   3/9/2020          7.0        2.0
# 15      AFG      Asia  Afghanistan  3/10/2020          8.0        1.0
# 16      AFG      Asia  Afghanistan  3/11/2020         11.0        3.0
# 17      AFG      Asia  Afghanistan  3/12/2020         12.0        1.0
# 18      AFG      Asia  Afghanistan  3/13/2020         13.0        1.0
# 19      AFG      Asia  Afghanistan  3/14/2020         15.0        2.0
#
#     new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                  NaN           NaN         NaN                  NaN  ...
# 1                  NaN           NaN         NaN                  NaN  ...
# 2                  NaN           NaN         NaN                  NaN  ...
# 3                  NaN           NaN         NaN                  NaN  ...
# 4                  NaN           NaN         NaN                  NaN  ...
# 5                0.143           NaN         NaN                  0.0  ...
# 6                0.143           NaN         NaN                  0.0  ...
# 7                0.000           NaN         NaN                  0.0  ...
# 8                0.143           NaN         NaN                  0.0  ...
# 9                0.429           NaN         NaN                  0.0  ...
# 10               0.429           NaN         NaN                  0.0  ...
# 11               0.429           NaN         NaN                  0.0  ...
# 12               0.429           NaN         NaN                  0.0  ...
# 13               0.571           NaN         NaN                  0.0  ...
# 14               0.857           NaN         NaN                  0.0  ...
# 15               0.857           NaN         NaN                  0.0  ...
# 16               1.000           NaN         NaN                  0.0  ...
# 17               1.143           NaN         NaN                  0.0  ...
# 18               1.286           NaN         NaN                  0.0  ...
# 19               1.571           NaN         NaN                  0.0  ...
#
#     gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0         1803.987              NaN                597.029
# 1         1803.987              NaN                597.029
# 2         1803.987              NaN                597.029
# 3         1803.987              NaN                597.029
# 4         1803.987              NaN                597.029
# 5         1803.987              NaN                597.029
# 6         1803.987              NaN                597.029
# 7         1803.987              NaN                597.029
# 8         1803.987              NaN                597.029
# 9         1803.987              NaN                597.029
# 10        1803.987              NaN                597.029
# 11        1803.987              NaN                597.029
# 12        1803.987              NaN                597.029
# 13        1803.987              NaN                597.029
# 14        1803.987              NaN                597.029
# 15        1803.987              NaN                597.029
# 16        1803.987              NaN                597.029
# 17        1803.987              NaN                597.029
# 18        1803.987              NaN                597.029
# 19        1803.987              NaN                597.029
#
#     diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                  9.59             NaN           NaN                  37.746
# 1                  9.59             NaN           NaN                  37.746
# 2                  9.59             NaN           NaN                  37.746
# 3                  9.59             NaN           NaN                  37.746
# 4                  9.59             NaN           NaN                  37.746
# 5                  9.59             NaN           NaN                  37.746
# 6                  9.59             NaN           NaN                  37.746
# 7                  9.59             NaN           NaN                  37.746
# 8                  9.59             NaN           NaN                  37.746
# 9                  9.59             NaN           NaN                  37.746
# 10                 9.59             NaN           NaN                  37.746
# 11                 9.59             NaN           NaN                  37.746
# 12                 9.59             NaN           NaN                  37.746
# 13                 9.59             NaN           NaN                  37.746
# 14                 9.59             NaN           NaN                  37.746
# 15                 9.59             NaN           NaN                  37.746
# 16                 9.59             NaN           NaN                  37.746
# 17                 9.59             NaN           NaN                  37.746
# 18                 9.59             NaN           NaN                  37.746
# 19                 9.59             NaN           NaN                  37.746
#
#     hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                          0.5            64.83                    0.498
# 1                          0.5            64.83                    0.498
# 2                          0.5            64.83                    0.498
# 3                          0.5            64.83                    0.498
# 4                          0.5            64.83                    0.498
# 5                          0.5            64.83                    0.498
# 6                          0.5            64.83                    0.498
# 7                          0.5            64.83                    0.498
# 8                          0.5            64.83                    0.498
# 9                          0.5            64.83                    0.498
# 10                         0.5            64.83                    0.498
# 11                         0.5            64.83                    0.498
# 12                         0.5            64.83                    0.498
# 13                         0.5            64.83                    0.498
# 14                         0.5            64.83                    0.498
# 15                         0.5            64.83                    0.498
# 16                         0.5            64.83                    0.498
# 17                         0.5            64.83                    0.498
# 18                         0.5            64.83                    0.498
# 19                         0.5            64.83                    0.498
#
# [20 rows x 59 columns]

# %%
# Merge two dataframes using an left outer join
merge_df = pd.merge(vaccinations_df, owid_data_df, on=["iso_code","date"], how='left')
merge_df.head()
# Out:
#    country iso_code       date  total_vaccinations_x  people_vaccinated_x  \
# 0  Algeria      DZA  1/29/2021                   0.0                  NaN
# 1  Algeria      DZA  1/30/2021                  30.0                  NaN
# 2  Andorra      AND  1/25/2021                 576.0                576.0
# 3  Andorra      AND  1/26/2021                   NaN                  NaN
# 4  Andorra      AND  1/27/2021                   NaN                  NaN
#
#    people_fully_vaccinated_x  daily_vaccinations_raw  daily_vaccinations  \
# 0                        NaN                     NaN                 NaN
# 1                        NaN                    30.0                30.0
# 2                        NaN                     NaN                 NaN
# 3                        NaN                     NaN                66.0
# 4                        NaN                     NaN                66.0
#
#    total_vaccinations_per_hundred_x  people_vaccinated_per_hundred_x  ...  \
# 0                              0.00                              NaN  ...
# 1                              0.00                              NaN  ...
# 2                              0.75                             0.75  ...
# 3                               NaN                              NaN  ...
# 4                               NaN                              NaN  ...
#
#    gdp_per_capita  extreme_poverty cardiovasc_death_rate diabetes_prevalence  \
# 0       13913.839              0.5               278.364                6.73
# 1       13913.839              0.5               278.364                6.73
# 2             NaN              NaN               109.135                7.97
# 3             NaN              NaN               109.135                7.97
# 4             NaN              NaN               109.135                7.97
#
#   female_smokers male_smokers handwashing_facilities  \
# 0            0.7         30.4                 83.741
# 1            0.7         30.4                 83.741
# 2           29.0         37.8                    NaN
# 3           29.0         37.8                    NaN
# 4           29.0         37.8                    NaN
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         1.9            76.88                    0.754
# 1                         1.9            76.88                    0.754
# 2                         NaN            83.73                    0.858
# 3                         NaN            83.73                    0.858
# 4                         NaN            83.73                    0.858
#
# [5 rows x 72 columns]

# %%
# look at columns to id which ones to delete
merge_df.columns
# Out:
# Index(['country', 'iso_code', 'date', 'total_vaccinations_x',
#        'people_vaccinated_x', 'people_fully_vaccinated_x',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred_x', 'people_vaccinated_per_hundred_x',
#        'people_fully_vaccinated_per_hundred_x',
#        'daily_vaccinations_per_million', 'vaccines', 'source_name',
#        'source_website', 'continent', 'location', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units',
#        'total_vaccinations_y', 'people_vaccinated_y',
#        'people_fully_vaccinated_y', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred_y',
#        'people_vaccinated_per_hundred_y',
#        'people_fully_vaccinated_per_hundred_y',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
merge_df.to_csv(path_or_buf="resources/merged_covid.csv", index=False)

# %%
merged_df_no_iso_code = merge_df.dropna(subset = ["iso_code"])
merged_df_no_iso_code.head()
#df.dropna(subset = ['column1_name', 'column2_name', 'column3_name'
# Out:
#    country iso_code       date  total_vaccinations_x  people_vaccinated_x  \
# 0  Algeria      DZA  1/29/2021                   0.0                  NaN
# 1  Algeria      DZA  1/30/2021                  30.0                  NaN
# 2  Andorra      AND  1/25/2021                 576.0                576.0
# 3  Andorra      AND  1/26/2021                   NaN                  NaN
# 4  Andorra      AND  1/27/2021                   NaN                  NaN
#
#    people_fully_vaccinated_x  daily_vaccinations_raw  daily_vaccinations  \
# 0                        NaN                     NaN                 NaN
# 1                        NaN                    30.0                30.0
# 2                        NaN                     NaN                 NaN
# 3                        NaN                     NaN                66.0
# 4                        NaN                     NaN                66.0
#
#    total_vaccinations_per_hundred_x  people_vaccinated_per_hundred_x  ...  \
# 0                              0.00                              NaN  ...
# 1                              0.00                              NaN  ...
# 2                              0.75                             0.75  ...
# 3                               NaN                              NaN  ...
# 4                               NaN                              NaN  ...
#
#    gdp_per_capita  extreme_poverty cardiovasc_death_rate diabetes_prevalence  \
# 0       13913.839              0.5               278.364                6.73
# 1       13913.839              0.5               278.364                6.73
# 2             NaN              NaN               109.135                7.97
# 3             NaN              NaN               109.135                7.97
# 4             NaN              NaN               109.135                7.97
#
#   female_smokers male_smokers handwashing_facilities  \
# 0            0.7         30.4                 83.741
# 1            0.7         30.4                 83.741
# 2           29.0         37.8                    NaN
# 3           29.0         37.8                    NaN
# 4           29.0         37.8                    NaN
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         1.9            76.88                    0.754
# 1                         1.9            76.88                    0.754
# 2                         NaN            83.73                    0.858
# 3                         NaN            83.73                    0.858
# 4                         NaN            83.73                    0.858
#
# [5 rows x 72 columns]

# %%
merged_df_no_iso_code.to_csv(path_or_buf="resources/merged_df_no_iso_code.csv", index=False)

# %%
# Reorganizing the columns using double brackets
organized_df = merged_df_no_iso_code[['country', 'iso_code', 'date', 'total_vaccinations_x',
       'people_vaccinated_x']]
organized_df.head()
# Out:
#    country iso_code       date  total_vaccinations_x  people_vaccinated_x
# 0  Algeria      DZA  1/29/2021                   0.0                  NaN
# 1  Algeria      DZA  1/30/2021                  30.0                  NaN
# 2  Andorra      AND  1/25/2021                 576.0                576.0
# 3  Andorra      AND  1/26/2021                   NaN                  NaN
# 4  Andorra      AND  1/27/2021                   NaN                  NaN
